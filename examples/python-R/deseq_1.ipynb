# %% [markdown]
# # Porting DESeq into python using rpy2#
#
# I will use a small example of [ERCC transcript](https://www.thermofisher.com/order/catalog/product/4456740) from [samples A and B in MAQC data](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3272078/).

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd 
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will read the table and it should only contains count data of ERCC spikeins (rows) and 3 replicates from each of samples A and B (columns).

# %%
df = pd.read_table('../test/data/ercc1.txt')
df.head()
# Out:
#   TargetName  disease3_scan | 001 | PanCK  disease3_scan | 001 | neg  \
# 0      PADI2                         15.0                       35.0
# 1    CYP24A1                         23.0                       32.0
# 2    SUPT16H                         35.0                       66.0
# 3      ZMIZ2                         51.0                       81.0
# 4      SPAG9                         48.0                       65.0
#
#    disease3_scan | 002 | PanCK  disease3_scan | 002 | neg  \
# 0                         36.0                       41.0
# 1                         23.0                       41.0
# 2                         46.0                       61.0
# 3                         87.0                      113.0
# 4                         46.0                       91.0
#
#    disease3_scan | 003 | PanCK  disease3_scan | 003 | neg  \
# 0                          9.0                       37.0
# 1                          3.0                       30.0
# 2                         20.0                       39.0
# 3                         68.0                       84.0
# 4                         25.0                       58.0
#
#    disease3_scan | 004 | PanCK  disease3_scan | 004 | neg  \
# 0                         42.0                       37.0
# 1                         34.0                       32.0
# 2                         79.0                       66.0
# 3                        164.0                      118.0
# 4                         95.0                       81.0
#
#    disease3_scan | 005 | PanCK  ...  disease1B_scan | 015 | Geometric Segment  \
# 0                         14.0  ...                                       1.0
# 1                         17.0  ...                                       1.0
# 2                         43.0  ...                                       1.0
# 3                         81.0  ...                                       3.0
# 4                         45.0  ...                                       8.0
#
#    disease1B_scan | 016 | Geometric Segment  \
# 0                                       1.0
# 1                                       1.0
# 2                                       3.0
# 3                                       2.0
# 4                                      10.0
#
#    disease1B_scan | 017 | Geometric Segment  \
# 0                                       3.0
# 1                                       1.0
# 2                                       2.0
# 3                                       2.0
# 4                                       7.0
#
#    disease1B_scan | 018 | Geometric Segment  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       3.0
#
#    disease1B_scan | 019 | Geometric Segment  \
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#
#    disease1B_scan | 020 | Geometric Segment  \
# 0                                       1.0
# 1                                       1.0
# 2                                       3.0
# 3                                       3.0
# 4                                       7.0
#
#    disease1B_scan | 021 | Geometric Segment  \
# 0                                       1.0
# 1                                       3.0
# 2                                       1.0
# 3                                       2.0
# 4                                       5.0
#
#    disease1B_scan | 022 | Geometric Segment  \
# 0                                       2.0
# 1                                       1.0
# 2                                       2.0
# 3                                       2.0
# 4                                       4.0
#
#    disease1B_scan | 023 | Geometric Segment  \
# 0                                       1.0
# 1                                       3.0
# 2                                       1.0
# 3                                       3.0
# 4                                       6.0
#
#    disease1B_scan | 024 | Geometric Segment
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       2.0
# 4                                       2.0
#
# [5 rows x 232 columns]

# %%
# df[["a", "b"]] = df[["a", "b"]].apply(pd.to_numeric)
df.loc[:, df.columns != 'TargetName'] = df.loc[:, df.columns != 'TargetName'].astype(int)
df.head()
# Out:
#   TargetName  disease3_scan | 001 | PanCK  disease3_scan | 001 | neg  \
# 0      PADI2                           15                         35
# 1    CYP24A1                           23                         32
# 2    SUPT16H                           35                         66
# 3      ZMIZ2                           51                         81
# 4      SPAG9                           48                         65
#
#    disease3_scan | 002 | PanCK  disease3_scan | 002 | neg  \
# 0                           36                         41
# 1                           23                         41
# 2                           46                         61
# 3                           87                        113
# 4                           46                         91
#
#    disease3_scan | 003 | PanCK  disease3_scan | 003 | neg  \
# 0                            9                         37
# 1                            3                         30
# 2                           20                         39
# 3                           68                         84
# 4                           25                         58
#
#    disease3_scan | 004 | PanCK  disease3_scan | 004 | neg  \
# 0                           42                         37
# 1                           34                         32
# 2                           79                         66
# 3                          164                        118
# 4                           95                         81
#
#    disease3_scan | 005 | PanCK  ...  disease1B_scan | 015 | Geometric Segment  \
# 0                           14  ...                                         1
# 1                           17  ...                                         1
# 2                           43  ...                                         1
# 3                           81  ...                                         3
# 4                           45  ...                                         8
#
#    disease1B_scan | 016 | Geometric Segment  \
# 0                                         1
# 1                                         1
# 2                                         3
# 3                                         2
# 4                                        10
#
#    disease1B_scan | 017 | Geometric Segment  \
# 0                                         3
# 1                                         1
# 2                                         2
# 3                                         2
# 4                                         7
#
#    disease1B_scan | 018 | Geometric Segment  \
# 0                                         1
# 1                                         1
# 2                                         1
# 3                                         1
# 4                                         3
#
#    disease1B_scan | 019 | Geometric Segment  \
# 0                                         1
# 1                                         1
# 2                                         1
# 3                                         1
# 4                                         1
#
#    disease1B_scan | 020 | Geometric Segment  \
# 0                                         1
# 1                                         1
# 2                                         3
# 3                                         3
# 4                                         7
#
#    disease1B_scan | 021 | Geometric Segment  \
# 0                                         1
# 1                                         3
# 2                                         1
# 3                                         2
# 4                                         5
#
#    disease1B_scan | 022 | Geometric Segment  \
# 0                                         2
# 1                                         1
# 2                                         2
# 3                                         2
# 4                                         4
#
#    disease1B_scan | 023 | Geometric Segment  \
# 0                                         1
# 1                                         3
# 2                                         1
# 3                                         3
# 4                                         6
#
#    disease1B_scan | 024 | Geometric Segment
# 0                                         1
# 1                                         1
# 2                                         1
# 3                                         2
# 4                                         2
#
# [5 rows x 232 columns]

# %% [markdown]
# And here, we will create a design matrix based on the samples in the count table. Note that the sample name has to be used as the ```pd.DataFrame``` index

# %%
sample_df = pd.read_table('../test/data/ercc2.txt')
sample_df.head()
# Out:
#   SlideName       ScanName  ROILabel       SegmentLabel  \
# 0  disease3  disease3_scan         7  Geometric Segment
# 1  disease3  disease3_scan         8  Geometric Segment
# 2  disease3  disease3_scan         9  Geometric Segment
# 3  disease3  disease3_scan        10  Geometric Segment
# 4  disease3  disease3_scan        11  Geometric Segment
#
#                         SegmentDisplayName                Sample_ID  \
# 0  disease3_scan | 007 | Geometric Segment  DSP-1001250007851-H-A02
# 1  disease3_scan | 008 | Geometric Segment  DSP-1001250007851-H-A03
# 2  disease3_scan | 009 | Geometric Segment  DSP-1001250007851-H-A04
# 3  disease3_scan | 010 | Geometric Segment  DSP-1001250007851-H-A05
# 4  disease3_scan | 011 | Geometric Segment  DSP-1001250007851-H-A06
#
#    AOISurfaceArea  AOINucleiCount  ROICoordinateX  ROICoordinateY  ...  \
# 0     31797.59253             202           11444          -18819  ...
# 1     16920.10267             102           13064          -20021  ...
# 2     14312.32987              98           14221          -18591  ...
# 3     20032.83995             143           12120          -17683  ...
# 4     27583.26127             195           12816          -16378  ...
#
#    SequencingSaturation  UMIQ30  RTSQ30  disease_status  pathology  \
# 0             90.586744  0.9939  0.9932             DKD   abnormal
# 1             90.707085  0.9948  0.9942             DKD   abnormal
# 2             87.861873  0.9949  0.9943             DKD   abnormal
# 3             89.399676  0.9925  0.9909             DKD   abnormal
# 4             89.958230  0.9934  0.9923             DKD   abnormal
#
#        region        LOQ  NormalizationFactor RoiReportX RoiReportY
# 0  glomerulus  24.246524             0.556033       1197      -3538
# 1  glomerulus  19.338643             0.820810       1606      -3834
# 2  glomerulus  17.017533             0.957612       1892      -3474
# 3  glomerulus  22.335012             0.718209       1366      -3245
# 4  glomerulus  24.703838             0.492486       1542      -2925
#
# [5 rows x 25 columns]

# %%
sample_df.index = sample_df.SegmentDisplayName
sample_df.head()
# Out:
#                                         SlideName       ScanName  ROILabel  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment  disease3  disease3_scan         7
# disease3_scan | 008 | Geometric Segment  disease3  disease3_scan         8
# disease3_scan | 009 | Geometric Segment  disease3  disease3_scan         9
# disease3_scan | 010 | Geometric Segment  disease3  disease3_scan        10
# disease3_scan | 011 | Geometric Segment  disease3  disease3_scan        11
#
#                                               SegmentLabel  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment  Geometric Segment
# disease3_scan | 008 | Geometric Segment  Geometric Segment
# disease3_scan | 009 | Geometric Segment  Geometric Segment
# disease3_scan | 010 | Geometric Segment  Geometric Segment
# disease3_scan | 011 | Geometric Segment  Geometric Segment
#
#                                                               SegmentDisplayName  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment  disease3_scan | 007 | Geometric Segment
# disease3_scan | 008 | Geometric Segment  disease3_scan | 008 | Geometric Segment
# disease3_scan | 009 | Geometric Segment  disease3_scan | 009 | Geometric Segment
# disease3_scan | 010 | Geometric Segment  disease3_scan | 010 | Geometric Segment
# disease3_scan | 011 | Geometric Segment  disease3_scan | 011 | Geometric Segment
#
#                                                        Sample_ID  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment  DSP-1001250007851-H-A02
# disease3_scan | 008 | Geometric Segment  DSP-1001250007851-H-A03
# disease3_scan | 009 | Geometric Segment  DSP-1001250007851-H-A04
# disease3_scan | 010 | Geometric Segment  DSP-1001250007851-H-A05
# disease3_scan | 011 | Geometric Segment  DSP-1001250007851-H-A06
#
#                                          AOISurfaceArea  AOINucleiCount  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment     31797.59253             202
# disease3_scan | 008 | Geometric Segment     16920.10267             102
# disease3_scan | 009 | Geometric Segment     14312.32987              98
# disease3_scan | 010 | Geometric Segment     20032.83995             143
# disease3_scan | 011 | Geometric Segment     27583.26127             195
#
#                                          ROICoordinateX  ROICoordinateY  ...  \
# SegmentDisplayName                                                       ...
# disease3_scan | 007 | Geometric Segment           11444          -18819  ...
# disease3_scan | 008 | Geometric Segment           13064          -20021  ...
# disease3_scan | 009 | Geometric Segment           14221          -18591  ...
# disease3_scan | 010 | Geometric Segment           12120          -17683  ...
# disease3_scan | 011 | Geometric Segment           12816          -16378  ...
#
#                                          SequencingSaturation  UMIQ30  RTSQ30  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment             90.586744  0.9939  0.9932
# disease3_scan | 008 | Geometric Segment             90.707085  0.9948  0.9942
# disease3_scan | 009 | Geometric Segment             87.861873  0.9949  0.9943
# disease3_scan | 010 | Geometric Segment             89.399676  0.9925  0.9909
# disease3_scan | 011 | Geometric Segment             89.958230  0.9934  0.9923
#
#                                          disease_status  pathology  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment             DKD   abnormal
# disease3_scan | 008 | Geometric Segment             DKD   abnormal
# disease3_scan | 009 | Geometric Segment             DKD   abnormal
# disease3_scan | 010 | Geometric Segment             DKD   abnormal
# disease3_scan | 011 | Geometric Segment             DKD   abnormal
#
#                                              region        LOQ  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment  glomerulus  24.246524
# disease3_scan | 008 | Geometric Segment  glomerulus  19.338643
# disease3_scan | 009 | Geometric Segment  glomerulus  17.017533
# disease3_scan | 010 | Geometric Segment  glomerulus  22.335012
# disease3_scan | 011 | Geometric Segment  glomerulus  24.703838
#
#                                          NormalizationFactor RoiReportX  \
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment             0.556033       1197
# disease3_scan | 008 | Geometric Segment             0.820810       1606
# disease3_scan | 009 | Geometric Segment             0.957612       1892
# disease3_scan | 010 | Geometric Segment             0.718209       1366
# disease3_scan | 011 | Geometric Segment             0.492486       1542
#
#                                         RoiReportY
# SegmentDisplayName
# disease3_scan | 007 | Geometric Segment      -3538
# disease3_scan | 008 | Geometric Segment      -3834
# disease3_scan | 009 | Geometric Segment      -3474
# disease3_scan | 010 | Geometric Segment      -3245
# disease3_scan | 011 | Geometric Segment      -2925
#
# [5 rows x 25 columns]

# %%
l2 = set(sample_df.SegmentDisplayName.unique())
l1 = set(df.columns[1:].tolist())
print(len(l1), len(l2))
# Out:
# 231 231

# %%
# using == to check if 
# lists are equal
if l1 == l2:
    print ("The lists are identical")
else :
    print ("The lists are not identical")
# Out:
# The lists are identical

# %% [markdown]
# Running DESeq2 is jsut like how it is run in ```R```, but instead of the row.name being gene ID for the count table, we can jsut tell the function which column is the gene ID:

# %%
from diffexpr.py_deseq import py_DESeq2

dds = py_DESeq2(count_matrix = df,
               design_matrix = sample_df,
               design_formula = '~ disease_status',
               gene_column = 'TargetName') # <- telling DESeq2 this should be the gene ID column
    
dds.run_deseq() 
dds.get_deseq_result(contrast = ['SlideName','disease3','normal3'])
res = dds.deseq_result 
res.head()
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Error in (function (countData, colData, design, tidy = FALSE, ignoreRank = FALSE,  :
#   rownames of the colData:
#    disease3_scan | 007 | Geometric Segment,disease3_scan | 008 | Geometric Segment,disease3_scan | 009 | Geometric Segment,disease3_scan | 010 | Geometric Segment,disease3_scan | 011 | Geometric Segment,disease3_scan | 012 | Geometric Segment,disease3_scan | 013 | Geometric Segment,disease3_scan | 014 | Geometric Segment,disease3_scan | 015 | Geometric Segment,disease3_scan | 016 | Geometric Segment,disease3_scan | 017 | Geometric Segment,disease3_scan | 018 | Geometric Segment,disease3_scan | 019 | Geometric Segment,disease3_scan | 020 | Geometric Segment,disease3_scan | 021 | Geometric Segment,disease3_scan | 022 | Geometric Segment,disease3_scan | 023 | Geometric Segment,disease3_scan | 024 | Geometric Segment,disease3_scan | 025 | Geometric Segment,disease3_scan | 026 | Geometric Segment,disease3_scan | 027 | Geometric Segment,disease3_scan | 028 | Geometric Segment,disease3_scan | 029 | Geometric Segment,disease3_scan | 030 | Geometric Segment,di
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-122-83861fa8b2b6> in <module>
#       4                design_matrix = sample_df,
#       5                design_formula = '~ disease_status',
# ----> 6                gene_column = 'TargetName') # <- telling DESeq2 this should be the gene ID column
#       7
#       8 dds.run_deseq()
#
# ~/anaconda3/envs/diffexpr/lib/python3.6/site-packages/diffexp-0.1-py3.6.egg/diffexpr/py_deseq.py in __init__(self, count_matrix, design_matrix, design_formula, gene_column)
#      64         self.dds = deseq.DESeqDataSetFromMatrix(countData=self.count_matrix,
#      65                                         colData=self.design_matrix,
# ---> 66                                         design=self.design_formula)
#      67
#      68
#
# ~/anaconda3/envs/diffexpr/lib/python3.6/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     197                 kwargs[r_k] = v
#     198         return (super(SignatureTranslatedFunction, self)
# --> 199                 .__call__(*args, **kwargs))
#     200
#     201
#
# ~/anaconda3/envs/diffexpr/lib/python3.6/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     123             else:
#     124                 new_kwargs[k] = conversion.py2rpy(v)
# --> 125         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     126         res = conversion.rpy2py(res)
#     127         return res
#
# ~/anaconda3/envs/diffexpr/lib/python3.6/site-packages/rpy2/rinterface_lib/conversion.py in _(*args, **kwargs)
#      43 def _cdata_res_to_rinterface(function):
#      44     def _(*args, **kwargs):
# ---> 45         cdata = function(*args, **kwargs)
#      46         # TODO: test cdata is of the expected CType
#      47         return _cdata_to_rinterface(cdata)
#
# ~/anaconda3/envs/diffexpr/lib/python3.6/site-packages/rpy2/rinterface.py in __call__(self, *args, **kwargs)
#     678             )
#     679             if error_occured[0]:
# --> 680                 raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     681         return res
#     682
#
# RRuntimeError: Error in (function (countData, colData, design, tidy = FALSE, ignoreRank = FALSE,  :
#   rownames of the colData:
#    disease3_scan | 007 | Geometric Segment,disease3_scan | 008 | Geometric Segment,disease3_scan | 009 | Geometric Segment,disease3_scan | 010 | Geometric Segment,disease3_scan | 011 | Geometric Segment,disease3_scan | 012 | Geometric Segment,disease3_scan | 013 | Geometric Segment,disease3_scan | 014 | Geometric Segment,disease3_scan | 015 | Geometric Segment,disease3_scan | 016 | Geometric Segment,disease3_scan | 017 | Geometric Segment,disease3_scan | 018 | Geometric Segment,disease3_scan | 019 | Geometric Segment,disease3_scan | 020 | Geometric Segment,disease3_scan | 021 | Geometric Segment,disease3_scan | 022 | Geometric Segment,disease3_scan | 023 | Geometric Segment,disease3_scan | 024 | Geometric Segment,disease3_scan | 025 | Geometric Segment,disease3_scan | 026 | Geometric Segment,disease3_scan | 027 | Geometric Segment,disease3_scan | 028 | Geometric Segment,disease3_scan | 029 | Geometric Segment,disease3_scan | 030 | Geometric Segment,di

# %%
dds.normalized_count() #DESeq2 normalized count

# %%
dds.comparison # show coefficients for GLM

# %%
# from the last cell, we see the arrangement of coefficients, 
# so that we can now use "coef" for lfcShrink
# the comparison we want to focus on is 'sample_B_vs_A', so coef = 4 will be used
lfc_res = dds.lfcShrink(coef=4, method='apeglm')
lfc_res.head()
